# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Halder/tutorial-1/blob/main/DataMiningTitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file1=r"/content/drive/MyDrive/dataset (2).csv"
file2=r"/content/drive/MyDrive/train1 (1).csv"
df=pd.read_csv(file1)
df1=pd.read_csv(file2)
print(df.head(10))
print(df1.head(10))
df.describe()
df1.describe()
df.shape
df.columns
df.dtypes
pclass23=df1[df1["Pclass"].isin([2,3])]
pclass23.head()
agenonull=df1[df1["Age"].notna()]
agenonull.head()
anames=df1.loc[df1["Age"]>35,"Name"]
anames.head()
df1.iloc[9:25,1:8]
a1=(df1.iloc[0:3,3]=="anonymous")
print(a1)
print("MEAN AGE OF PASSENGER ON BOARD",df1["Age"].mean())
print("MEDIAN VALUE OF PASSENGER AGE AND FARE ON BOARD",df1[["Age","Fare"]].median())
df1[["Age","Fare"]].describe()
df1[["Age","Sex"]].groupby("Sex").mean()
df1[["Age","Fare"]].describe()
df1[["Age","Sex"]].groupby("Sex").max()
df1[["Age","Sex"]].groupby("Sex").min()
df1[["Age","Sex"]].groupby("Sex").first()
df1.groupby(["Sex","Pclass"])["Fare"].mean()
df1.groupby("Sex")["Age"].mean()
df1["Pclass"].value_counts()
df1.groupby("Pclass")["Pclass"].count()
df1.sort_values(by="Age",ascending=True).head()
df1.sort_values(by=["Pclass","Age"],ascending=False).head()
df1["Name"].str.lower()
print(df1.head())
df1["Name"].str.split(",")
df1["surname"]=df1["Name"].str.split(",").str.get(1)
print("SURNAME OF THE PASSENGER",df1["surname"])
df1["RealName"]=df1["Name"].str.split(",").str.get(0)
print("REAL NAME OF THE PASSENGER",df1["RealName"])
df1["Salutions"]=df1["surname"].str.split(",").str.get(0)
df1.head()
df1["Salutions"]=df1["surname"].str.split(",").str.get(1)
df1.head()
df1["Name"].str.contains("Mr")
df1["Name"].str.contains("Miss")
df1[df1["Name"].str.contains("Countess")]
df1["Name"].str.len()
df1.loc[df1["Name"].str.len().idxmax(),"Name"]
df1["SHORTGENDER"]=df1["Sex"].replace({"male":"M","female":"F"})
df1.head()
print(df1["SHORTGENDER"])
df1.corr()
# Out:
#   Customer ID Purchase Date Product ID  Price  Discount
# 0        C001      1/1/2022       P001    100        10
# 1        C002      1/2/2022       P002    150        15
# 2        C003      1/3/2022       P003    200        20
# 3        C004      1/4/2022       P001    100        10
# 4        C005      1/5/2022       P002    150        15
# 5        C006      1/6/2022       P003    200        20
# 6        C007      1/7/2022       P004     75         5
# 7        C008      1/8/2022       P005    125        10
# 8        C009      1/9/2022       P006    300        30
# 9        C010     1/10/2022       P001    100        10
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# ...
